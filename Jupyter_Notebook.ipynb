# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# My name: **Ramon Ohnesorge Moraes.**
#
# Desired occupation: Data Scientist/Data Analyst.

# %% [markdown]
# My interests in Data Science includes (but is not limited to):
# 1. *Find insights in general data.*
# 1. *Determine preventivaly oil & gas wells needs for workover.*
# 1. *Analyse and predict present and future integrity state of oil & gas wells.*

# %% [markdown]
# ### The code bellow will give the approximate value of the Riemann Zeta Function at 2, or Zeta(2):

# %%
sum = 0
for i in range(1,1000):
    sum = sum + 1/i**2

print("Approximate value of Zeta(2) = ", sum)
# Out:
# Approximate value of Zeta(2) =  1.6439335666815615

# %% [markdown]
# _________________________________________________________________________
#
# This is a bulleted list:
# * First one.
# * Second.
# * Third and final one.
#
# This is a numbered list:
# 1. First one.
# 1. Second.
#  1. Inside the second.
# 1. Third and final one.
#
# | Item | Cost | Retail Value |
# | --- | --- | --- |
# | Car | 10.000 | 20.000 |
# | Bike | 5.000 | 10.000 |
